# %%
import seaborn as sns  #importing seaborn
import pandas as pd

path='/content/IRIS.csv'
df=pd.read_csv('IRIS.csv')

# %%
df.shape  #shape of dataset
# Out:
# (150, 5)

# %%
type(df)  #type of dataset #it is in dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=df)

# %%
df  #dataset for reference
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue="species")   #pairplot for species in iris dataset :species incluse setosa versicolor virginica

# %%
sns.set_theme(style="darkgrid")  #just styling the graph the darkgrid style in background
sns.lineplot(x="sepal_length", y="petal_length", hue="species" ,data=df)

# %%
sns.barplot(x="sepal_length", y="petal_length", hue="species",capsize=.2 ,data=df)

# %%
sns.pointplot(x="sepal_length", y="petal_length", hue="species" ,data=df)

# %%
sns.countplot(data=df)

# %%
import matplotlib.pyplot as plt

sns.kdeplot(data=df, color='green', shade=True) 
  
# Setting the X and Y Label 
plt.xlabel('length and width of sepal and petals') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(data=df, x="sepal_length")   #kde plot for sepal_length

# %%
sns.displot(data=df, x="sepal_length", col="species", kde=True)

# %%
sns.displot(data=df, x="sepal_width", col="species", kde=True)
